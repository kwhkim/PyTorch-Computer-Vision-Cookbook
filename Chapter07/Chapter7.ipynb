# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
# Out:
# /home/ubuntu/anaconda3/envs/p38torch-pip/bin/python
# 3.8.8 (default, Feb 24 2021, 21:46:12)
# [GCC 7.3.0]
# sys.version_info(major=3, minor=8, micro=8, releaselevel='final', serial=0)

# %%
#pip install ipykernel
#python -m ipykernel install --user --name [virtualEnv] --display-name "[displayKenrelName]"

# %%
#https://stackoverflow.com/questions/46767012/conda-list-shows-a-package-but-cannot-import-it

# %% [markdown]
# ## Creating the Dataset

# %%
from torchvision.datasets import VOCSegmentation
from PIL import Image   
from torchvision.transforms.functional import to_tensor, to_pil_image

# %%
class myVOCSegmentation(VOCSegmentation):
    def __getitem__(self, index):
        img = Image.open(self.images[index]).convert('RGB')
        target = Image.open(self.masks[index])

        if self.transforms is not None:
            augmented= self.transforms(image=np.array(img), mask=np.array(target))
            img = augmented['image']
            target = augmented['mask']                  
            target[target>20]=0

        img= to_tensor(img)            
        target= torch.from_numpy(target).type(torch.long)
        return img, target

# %%
from albumentations import (
    HorizontalFlip,
    Compose,
    Resize,
    Normalize)

mean = [0.485, 0.456, 0.406] 
std = [0.229, 0.224, 0.225]
h,w=520,520

transform_train = Compose([ Resize(h,w),
                HorizontalFlip(p=0.5), 
                Normalize(mean=mean,std=std)])

transform_val = Compose( [ Resize(h,w),
                          Normalize(mean=mean,std=std)])

# %%
# %ls ../../../data/voc2012
# Out:
# VOCdevkit/  VOCtrainval_11-May-2012.tar

# %%
path2data="../../../data/voc2012"    
train_ds=myVOCSegmentation(path2data, 
                year='2012', 
                image_set='train', 
                download=True, 
                transforms=transform_train) 
print(len(train_ds))
# Out:
# Using downloaded and verified file: ../../../data/voc2012/VOCtrainval_11-May-2012.tar
# Extracting ../../../data/voc2012/VOCtrainval_11-May-2012.tar to ../../../data/voc2012
# 1464

# %%
val_ds=myVOCSegmentation(path2data, 
                year='2012', 
                image_set='val', 
                download=False, 
                transforms=transform_val)
print(len(val_ds))
# Out:
# 1449

# %%
import torch
import numpy as np
from skimage.segmentation import mark_boundaries
import matplotlib.pylab as plt
# %matplotlib inline
np.random.seed(0)
num_classes=21
COLORS = np.random.randint(0, 2, size=(num_classes+1, 3),dtype="uint8")

# %%
def show_img_target(img, target):
    if torch.is_tensor(img):
        img=to_pil_image(img)
        target=target.numpy()
    for ll in range(num_classes):
        mask=(target==ll)
        img=mark_boundaries(np.array(img) , 
                            mask,
                            outline_color=COLORS[ll],
                            color=COLORS[ll])
    plt.imshow(img)

# %%
def re_normalize (x, mean = mean, std= std):
    x_r= x.clone()
    for c, (mean_c, std_c) in enumerate(zip(mean, std)):
        x_r [c] *= std_c
        x_r [c] += mean_c
    return x_r

# %%
img, mask = train_ds[6]
print(img.shape, img.type(),torch.max(img))
print(mask.shape, mask.type(),torch.max(mask))
# Out:
# torch.Size([3, 520, 520]) torch.FloatTensor tensor(2.6400)
# torch.Size([520, 520]) torch.LongTensor tensor(4)

# %%
plt.figure(figsize=(20,20))

img_r= re_normalize(img)
plt.subplot(1, 3, 1) 
plt.imshow(to_pil_image(img_r))

plt.subplot(1, 3, 2) 
plt.imshow(mask)

plt.subplot(1, 3, 3) 
show_img_target(img_r, mask)

# %%
img, mask = val_ds[0]
print(img.shape, img.type(),torch.max(img))
print(mask.shape, mask.type(),torch.max(mask))
# Out:
# torch.Size([3, 520, 520]) torch.FloatTensor tensor(2.6226)
# torch.Size([520, 520]) torch.LongTensor tensor(1)

# %%
plt.figure(figsize=(20,20))

img_r= re_normalize(img)
plt.subplot(1, 3, 1) 
plt.imshow(to_pil_image(img_r))

plt.subplot(1, 3, 2) 
plt.imshow(mask)

plt.subplot(1, 3, 3) 
show_img_target(img_r, mask)

# %% [markdown]
# ### Creating DataLoader

# %%
from torch.utils.data import DataLoader
train_dl = DataLoader(train_ds, batch_size=4, shuffle=True)
val_dl = DataLoader(val_ds, batch_size=8, shuffle=False)

# %%
for img_b, mask_b in train_dl:
    print(img_b.shape,img_b.dtype)
    print(mask_b.shape, mask_b.dtype)
    break
# Out:
# torch.Size([4, 3, 520, 520]) torch.float32
# torch.Size([4, 520, 520]) torch.int64

# %%
for img_b, mask_b in val_dl:
    print(img_b.shape,img_b.dtype)
    print(mask_b.shape, mask_b.dtype)
    break
# Out:
# torch.Size([8, 3, 520, 520]) torch.float32
# torch.Size([8, 520, 520]) torch.int64

# %% [markdown]
# # Creating the Model

# %%
from torchvision.models.segmentation import deeplabv3_resnet101
import torch

# %%
model=deeplabv3_resnet101(pretrained=True, num_classes=21)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model=model.to(device)

# %%
#https://stackoverflow.com/questions/714063/importing-modules-from-parent-folder/28712742#comment102640654_28712742
import os
import sys
sys.path.insert(1, os.path.join(sys.path[0], '..'))
import torchsummary

# %%
#torchsummary(model)
# TypeError: 'module' object is not callable

# %%
#print(model)

# %% [markdown]
# ## Deploying the Model

# %%
from torch import nn

model.eval()
with torch.no_grad():
    for xb, yb in val_dl:
        yb_pred = model(xb.to(device))
        yb_pred = yb_pred["out"].cpu()
        print(yb_pred.shape)    
        yb_pred = torch.argmax(yb_pred,axis=1)
        break
print(yb_pred.shape)
# Out:
# torch.Size([8, 21, 520, 520])
# torch.Size([8, 520, 520])

# %%
plt.figure(figsize=(20,20))

#n=4
n=5
img, mask= xb[n], yb_pred[n]
img_r= re_normalize(img)
plt.subplot(1, 3, 1) 
plt.imshow(to_pil_image(img_r))

plt.subplot(1, 3, 2) 
plt.imshow(mask)

plt.subplot(1, 3, 3) 
show_img_target(img_r, mask)

# %% [markdown]
# ## Define Loss Function

# %%
from torch import nn
criterion = nn.CrossEntropyLoss(reduction="sum")

# %% [markdown]
# ## Optimizer

# %%
from torch import optim
opt = optim.Adam(model.parameters(), lr=1e-6)

# %%
def loss_batch(loss_func, output, target, opt=None):   
    loss = loss_func(output, target)
    
    if opt is not None:
        opt.zero_grad()
        loss.backward()
        opt.step()

    return loss.item(), None

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(opt, mode='min',factor=0.5, patience=20,verbose=1)

# %%
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']

current_lr=get_lr(opt)
print('current lr={}'.format(current_lr))
# Out:
# current lr=1e-06

# %% [markdown]
# ## Training the Model

# %%
def loss_epoch(model,loss_func,dataset_dl,sanity_check=False,opt=None):
    running_loss=0.0
    len_data=len(dataset_dl.dataset)

    for xb, yb in dataset_dl:
        xb=xb.to(device)
        yb=yb.to(device)
        
        output=model(xb)["out"]
        loss_b, _ = loss_batch(loss_func, output, yb, opt)
        running_loss += loss_b
        
        if sanity_check is True:
            break
    
    loss=running_loss/float(len_data)
    return loss, None

# %%
import copy
def train_val(model, params):
    num_epochs=params["num_epochs"]
    loss_func=params["loss_func"]
    opt=params["optimizer"]
    train_dl=params["train_dl"]
    val_dl=params["val_dl"]
    sanity_check=params["sanity_check"]
    lr_scheduler=params["lr_scheduler"]
    path2weights=params["path2weights"]
    
    loss_history={
        "train": [],
        "val": []}
    
    metric_history={
        "train": [],
        "val": []}    
    
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss=float('inf')    
    
    for epoch in range(num_epochs):
        current_lr=get_lr(opt)
        print('Epoch {}/{}, current lr={}'.format(epoch, num_epochs - 1, current_lr))   

        model.train()
        train_loss, train_metric=loss_epoch(model,loss_func,train_dl,sanity_check,opt)

        loss_history["train"].append(train_loss)
        metric_history["train"].append(train_metric)
        
        model.eval()
        with torch.no_grad():
            val_loss, val_metric=loss_epoch(model,loss_func,val_dl,sanity_check)
       
        loss_history["val"].append(val_loss)
        metric_history["val"].append(val_metric)   
        
        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            
            torch.save(model.state_dict(), path2weights)
            print("Copied best model weights!")
            
        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print("Loading best model weights!")
            model.load_state_dict(best_model_wts) 
            
        print("train loss: %.6f" %(train_loss))
        print("val loss: %.6f" %(val_loss))
        print("-"*10) 
    model.load_state_dict(best_model_wts)
    return model, loss_history, metric_history

# %%
import os
opt = optim.Adam(model.parameters(), lr=1e-6)
lr_scheduler = ReduceLROnPlateau(opt, mode='min',factor=0.5, patience=20,verbose=1)

path2models= "./models/"
if not os.path.exists(path2models):
        os.mkdir(path2models)

params_train={
    "num_epochs": 100,
    "optimizer": opt,
    "loss_func": criterion,
    "train_dl": train_dl,
    "val_dl": val_dl,
    "sanity_check": True,
    "lr_scheduler": lr_scheduler,
    "path2weights": path2models+"sanity_weights.pt",
}

model, loss_hist, _ = train_val(model, params_train)
# Out:
# Epoch 0/99, current lr=1e-06
# Copied best model weights!
# train loss: 228.375897
# val loss: 227.474163
# ----------
# Epoch 1/99, current lr=1e-06
# Copied best model weights!
# train loss: 140.138234
# val loss: 226.063039
# ----------
# Epoch 2/99, current lr=1e-06
# Copied best model weights!
# train loss: 211.112470
# val loss: 221.990446
# ----------
# Epoch 3/99, current lr=1e-06
# train loss: 108.936603
# val loss: 227.401872
# ----------
# Epoch 4/99, current lr=1e-06
# train loss: 316.468195
# val loss: 232.728347
# ----------
# Epoch 5/99, current lr=1e-06
# train loss: 76.821855
# val loss: 234.112384
# ----------
# Epoch 6/99, current lr=1e-06
# train loss: 193.550098
# val loss: 231.051350
# ----------
# Epoch 7/99, current lr=1e-06
# train loss: 401.913678
# val loss: 234.172878
# ----------
# Epoch 8/99, current lr=1e-06
# train loss: 89.864562
# val loss: 226.463423
# ----------
# Epoch 9/99, current lr=1e-06
# train loss: 130.231024
# val loss: 222.657242
# ----------
# Epoch 10/99, current lr=1e-06
# train loss: 122.161907
# val loss: 229.264493
# ----------
# Epoch 11/99, current lr=1e-06
# Copied best model weights!
# train loss: 82.951738
# val loss: 221.443258
# ----------
# Epoch 12/99, current lr=1e-06
# Copied best model weights!
# train loss: 57.404350
# val loss: 217.092866
# ----------
# Epoch 13/99, current lr=1e-06
# train loss: 158.678353
# val loss: 219.199232
# ----------
# Epoch 14/99, current lr=1e-06
# train loss: 87.430050
# val loss: 224.983803
# ----------
# Epoch 15/99, current lr=1e-06
# train loss: 632.294314
# val loss: 228.580875
# ----------
# Epoch 16/99, current lr=1e-06
# train loss: 95.443904
# val loss: 226.911102
# ----------
# Epoch 17/99, current lr=1e-06
# train loss: 575.604892
# val loss: 227.809955
# ----------
# Epoch 18/99, current lr=1e-06
# train loss: 496.609717
# val loss: 223.779331
# ----------
# Epoch 19/99, current lr=1e-06
# train loss: 2320.093238
# val loss: 224.881944
# ----------
# Epoch 20/99, current lr=1e-06
# train loss: 472.360613
# val loss: 227.087323
# ----------
# Epoch 21/99, current lr=1e-06
# train loss: 210.258730
# val loss: 220.301997
# ----------
# Epoch 22/99, current lr=1e-06
# train loss: 142.997545
# val loss: 217.637293
# ----------
# Epoch 23/99, current lr=1e-06
# Copied best model weights!
# train loss: 73.038945
# val loss: 215.996528
# ----------
# Epoch 24/99, current lr=1e-06
# Copied best model weights!
# train loss: 300.127071
# val loss: 214.513824
# ----------
# Epoch 25/99, current lr=1e-06
# Copied best model weights!
# train loss: 303.597037
# val loss: 214.172554
# ----------
# Epoch 26/99, current lr=1e-06
# Copied best model weights!
# train loss: 780.207565
# val loss: 204.482229
# ----------
# Epoch 27/99, current lr=1e-06
# train loss: 134.102139
# val loss: 207.449168
# ----------
# Epoch 28/99, current lr=1e-06
# train loss: 153.531015
# val loss: 210.067611
# ----------
# Epoch 29/99, current lr=1e-06
# train loss: 82.702068
# val loss: 210.278986
# ----------
# Epoch 30/99, current lr=1e-06
# train loss: 588.059085
# val loss: 212.010848
# ----------
# Epoch 31/99, current lr=1e-06
# train loss: 213.333397
# val loss: 208.988483
# ----------
# Epoch 32/99, current lr=1e-06
# train loss: 122.098713
# val loss: 212.656056
# ----------
# Epoch 33/99, current lr=1e-06
# Copied best model weights!
# train loss: 166.562158
# val loss: 204.051544
# ----------
# Epoch 34/99, current lr=1e-06
# Copied best model weights!
# train loss: 71.785999
# val loss: 202.060408
# ----------
# Epoch 35/99, current lr=1e-06
# Copied best model weights!
# train loss: 57.000768
# val loss: 201.569250
# ----------
# Epoch 36/99, current lr=1e-06
# train loss: 103.021036
# val loss: 206.734192
# ----------
# Epoch 37/99, current lr=1e-06
# train loss: 352.836535
# val loss: 203.989389
# ----------
# Epoch 38/99, current lr=1e-06
# train loss: 138.836407
# val loss: 204.253925
# ----------
# Epoch 39/99, current lr=1e-06
# train loss: 124.012316
# val loss: 203.533838
# ----------
# Epoch 40/99, current lr=1e-06
# train loss: 690.309853
# val loss: 204.555707
# ----------
# Epoch 41/99, current lr=1e-06
# train loss: 285.558615
# val loss: 209.146890
# ----------
# Epoch 42/99, current lr=1e-06
# train loss: 158.007119
# val loss: 211.803658
# ----------
# Epoch 43/99, current lr=1e-06
# train loss: 404.648992
# val loss: 213.919190
# ----------
# Epoch 44/99, current lr=1e-06
# train loss: 171.006756
# val loss: 219.994867
# ----------
# Epoch 45/99, current lr=1e-06
# train loss: 160.919036
# val loss: 212.776592
# ----------
# Epoch 46/99, current lr=1e-06
# train loss: 227.678684
# val loss: 218.505305
# ----------
# Epoch 47/99, current lr=1e-06
# train loss: 121.175418
# val loss: 217.669859
# ----------
# Epoch 48/99, current lr=1e-06
# train loss: 218.455281
# val loss: 223.447464
# ----------
# Epoch 49/99, current lr=1e-06
# train loss: 120.750672
# val loss: 225.234774
# ----------
# Epoch 50/99, current lr=1e-06
# train loss: 262.937799
# val loss: 230.213725
# ----------
# Epoch 51/99, current lr=1e-06
# train loss: 327.929816
# val loss: 230.472028
# ----------
# Epoch 52/99, current lr=1e-06
# train loss: 204.197511
# val loss: 227.105504
# ----------
# Epoch 53/99, current lr=1e-06
# train loss: 143.878501
# val loss: 233.214695
# ----------
# Epoch 54/99, current lr=1e-06
# train loss: 124.869269
# val loss: 238.934481
# ----------
# Epoch 55/99, current lr=1e-06
# train loss: 352.698066
# val loss: 244.884791
# ----------
# Epoch 56/99, current lr=1e-06
# Epoch    57: reducing learning rate of group 0 to 5.0000e-07.
# Loading best model weights!
# train loss: 107.796309
# val loss: 250.650858
# ----------
# Epoch 57/99, current lr=5e-07
# train loss: 110.625256
# val loss: 204.100069
# ----------
# Epoch 58/99, current lr=5e-07
# Copied best model weights!
# train loss: 314.828104
# val loss: 198.931030
# ----------
# Epoch 59/99, current lr=5e-07
# train loss: 132.494600
# val loss: 203.853153
# ----------
# Epoch 60/99, current lr=5e-07
# train loss: 83.512589
# val loss: 210.846014
# ----------
# Epoch 61/99, current lr=5e-07
# train loss: 192.272263
# val loss: 207.779331
# ----------
# Epoch 62/99, current lr=5e-07
# train loss: 213.213008
# val loss: 218.884705
# ----------
# Epoch 63/99, current lr=5e-07
# train loss: 228.810152
# val loss: 222.892771
# ----------
# Epoch 64/99, current lr=5e-07
# train loss: 89.040813
# val loss: 227.926717
# ----------
# Epoch 65/99, current lr=5e-07
# train loss: 237.419570
# val loss: 228.842607
# ----------
# Epoch 66/99, current lr=5e-07
# train loss: 100.767034
# val loss: 236.884058
# ----------
# Epoch 67/99, current lr=5e-07
# train loss: 236.041795
# val loss: 229.802126
# ----------
# Epoch 68/99, current lr=5e-07
# train loss: 363.905225
# val loss: 225.922835
# ----------
# Epoch 69/99, current lr=5e-07
# train loss: 311.850388
# val loss: 223.846597
# ----------
# Epoch 70/99, current lr=5e-07
# train loss: 658.478526
# val loss: 221.112319
# ----------
# Epoch 71/99, current lr=5e-07
# train loss: 145.435344
# val loss: 224.852269
# ----------
# Epoch 72/99, current lr=5e-07
# train loss: 444.084742
# val loss: 220.836568
# ----------
# Epoch 73/99, current lr=5e-07
# train loss: 77.590436
# val loss: 225.123857
# ----------
# Epoch 74/99, current lr=5e-07
# train loss: 453.356387
# val loss: 226.923719
# ----------
# Epoch 75/99, current lr=5e-07
# train loss: 287.935259
# val loss: 236.155064
# ----------
# Epoch 76/99, current lr=5e-07
# train loss: 73.065206
# val loss: 228.708031
# ----------
# Epoch 77/99, current lr=5e-07
# train loss: 186.941129
# val loss: 230.720109
# ----------
# Epoch 78/99, current lr=5e-07
# train loss: 227.068477
# val loss: 226.128494
# ----------
# Epoch 79/99, current lr=5e-07
# Epoch    80: reducing learning rate of group 0 to 2.5000e-07.
# Loading best model weights!
# train loss: 297.637338
# val loss: 236.540459
# ----------
# Epoch 80/99, current lr=2.5e-07
# train loss: 132.373986
# val loss: 203.899327
# ----------
# Epoch 81/99, current lr=2.5e-07
# train loss: 728.461151
# val loss: 202.371657
# ----------
# Epoch 82/99, current lr=2.5e-07
# train loss: 111.561561
# val loss: 205.100673
# ----------
# Epoch 83/99, current lr=2.5e-07
# train loss: 2202.210041
# val loss: 205.576195
# ----------
# Epoch 84/99, current lr=2.5e-07
# train loss: 1301.402322
# val loss: 209.738182
# ----------
# Epoch 85/99, current lr=2.5e-07
# train loss: 394.480704
# val loss: 214.343642
# ----------
# Epoch 86/99, current lr=2.5e-07
# train loss: 255.949155
# val loss: 215.630435
# ----------
# Epoch 87/99, current lr=2.5e-07
# train loss: 358.104295
# val loss: 216.776268
# ----------
# Epoch 88/99, current lr=2.5e-07
# train loss: 151.381126
# val loss: 230.262509
# ----------
# Epoch 89/99, current lr=2.5e-07
# train loss: 180.175120
# val loss: 240.167227
# ----------
# Epoch 90/99, current lr=2.5e-07
# train loss: 187.514728
# val loss: 240.963445
# ----------
# Epoch 91/99, current lr=2.5e-07
# train loss: 144.848371
# val loss: 229.813190
# ----------
# Epoch 92/99, current lr=2.5e-07
# train loss: 114.101296
# val loss: 228.599573
# ----------
# Epoch 93/99, current lr=2.5e-07
# train loss: 358.430029
# val loss: 224.290696
# ----------
# Epoch 94/99, current lr=2.5e-07
# train loss: 128.018443
# val loss: 236.616352
# ----------
# Epoch 95/99, current lr=2.5e-07
# train loss: 1503.036885
# val loss: 245.472071
# ----------
# Epoch 96/99, current lr=2.5e-07
# train loss: 706.822319
# val loss: 241.990295
# ----------
# Epoch 97/99, current lr=2.5e-07
# train loss: 127.480181
# val loss: 247.211353
# ----------
# Epoch 98/99, current lr=2.5e-07
# train loss: 219.967853
# val loss: 242.142857
# ----------
# Epoch 99/99, current lr=2.5e-07
# train loss: 180.190958
# val loss: 241.809157
# ----------

# %%
num_epochs=params_train["num_epochs"]

plt.title("Train-Val Loss")
plt.plot(range(1,num_epochs+1),loss_hist["train"],label="train")
plt.plot(range(1,num_epochs+1),loss_hist["val"],label="val")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()
